# %% [markdown]
# # Access to endpoint and data sources CORD19-NEKG
# ### maintaned by WIMMICS team
#
# This notebook is intended to be used as a client to the dataset called CORD-19 Named Entities Knowledge Graph (CORD19-NEKG): it describes the named entities identified in the 47,000+ articles provided by the COVID-19 Open Research Dataset (CORD-19).
#
# For now, the named entities published are those identified by DBpedia Spotlight (DBpedia URIs) and entity-fishing (Wikidata URIs) in articles' titles and abstracts.
#
# You can query the dataset from our Virtuoso endpoint: https://covid19.i3s.unice.fr/sparql. Here are the relevant named graphs:
#     http://ns.inria.fr/covid19/graph/metadata: dataset description + definition of a few properties
#     http://ns.inria.fr/covid19/graph/articles: articles metadata (title, authors, DOIs, journal etc.)
#     http://ns.inria.fr/covid19/graph/dbpedia-spotlight: named entities identified by DBpedia Spotlight => 1,835,902 named entities
#     http://ns.inria.fr/covid19/graph/entityfishing: named entities identified by Entity-fishing => 790,922 named entities
#
# The dataset is described here: https://github.com/Wimmics/cord19-nekg
# More specifically, you shall find details on how named entities are represented in RDF in that page: https://github.com/Wimmics/cord19-nekg/blob/master/doc/01-data-modeling.md

# %%
from __future__ import print_function

# %% [markdown]
# ## Install required packages
#
# #### SPARQLWrapper
#
# This package helps to convert service output to a Pandas DataFrame. https://rdflib.dev/sparqlwrapper/
#
# #### Pandas
#
# Using Pandas DataFrame to contain the query results.
#
#
# NOTE: if you are runing Anaconda distribution the prefered way to install packages:
#
# _conda install -c conda-forge sparqlwrapper_
#
# _conda install pandas_
#
# Only run it once or periodically to check for the updates.

# %%
# !pip install pandas

# %%
# !pip install SPARQLWrapper

# %%
import pandas as pd
print('Pandas ver.', pd.__version__)

import SPARQLWrapper
import json
print('SPARQLWrapper ver.', SPARQLWrapper.__version__)

from SPARQLWrapper import SPARQLWrapper, JSON
# Out:
# Pandas ver. 1.0.2
# SPARQLWrapper ver. 1.8.2

# %%
def sparql_service_to_dataframe(service, query):
    """
    Helper function to convert SPARQL results into a Pandas DataFrame.
    
    Credit to Ted Lawless https://lawlesst.github.io/notebook/sparql-dataframe.html
    """
    sparql = SPARQLWrapper(service)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

# %% [markdown]
# # Run queries

# %%
wds_Corese_Covid = 'https://covid19.i3s.unice.fr/sparql'

# %%
# Select articles with a reference to "coronavirus" 
query = '''
SELECT (group_concat(distinct ?name,", ") AS ?authors)
       # ?title 
       (year(?date) as ?year)
       # ?pub
       # ?url
       #(sample(?) as ?annotation)
WHERE {
    graph <http://ns.inria.fr/covid19/graph/articles>
    {
        # ?doc a ?t;
            dce:creator ?name;
            dct:title ?title;
            schema:publication ?pub;
            schema:url ?url;
            dct:abstract [ rdf:value ?abs ].

        optional { ?doc dct:issued ?date }
        filter contains(?abs, "asymptomatic infection")
    }
    
    #graph <http://ns.inria.fr/covid19/graph/entityfishing> {
    #?a1 a oa:Annotation;
    #    schema:about ?doc;
    #    dct:subject ?an;
    #    oa:hasBody ?uri.
  #}
} 
group by ?doc ?title ?date ?pub ?url
order by desc(?date)
limit 10
	
'''

# %%
# %time df = sparql_service_to_dataframe(wds_Corese_Covid, query)
print(df.shape)
# Out:
# Wall time: 1.76 s
# (10, 5)

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.precision', 3)
pd.set_option('display.max_rows', 9999)

df.head()
# Out:
#                                                                                                   authors  \
# 0  Chen, Shey-Ying, Hsueh, Po-Ren, King, Chwan-Chuen, Schwartz, Jonathan, Yang, Guang-Yang, Yen, Muh-Yong
# 1                                                                       Chang, Le, Wang, Lunan, Yan, Ying
# 2                                                              Ho, Yi-Jung, Lai, Zheng-Zong, Lu, Jeng-Wei
# 3                                                                                         Alenazi, Thamer
# 4                              Dong, Chao, Long, Ting, Pan, Yaohui, Shi, Tianyu, Yin, Qiuju, Zhang, Wensi
#
#                                                                                                                                           title  \
# 0  Interrupting COVID-19 transmission by implementing enhanced traffic control bundling: Implications for global prevention and control efforts
# 1                                                                                      Coronavirus Disease 2019: Coronaviruses and Blood Safety
# 2                                                             Cephalotaxine inhibits Zika infection by impeding viral replication and stability
# 3                                                                                      Severe Middle East Respiratory Syndrome (MERS) Pneumonia
# 4                  Effects of asymptomatic infection on the dynamical interplay between behavior and disease transmission in multiplex networks
#
#    year                                                    pub  \
# 0  2020      Journal of Microbiology, Immunology and Infection
# 1  2020                           Transfusion Medicine Reviews
# 2  2020    Biochemical and Biophysical Research Communications
# 3  2019                Reference Module in Biomedical Sciences
# 4  2019  Physica A: Statistical Mechanics and its Applications
#
#                                                   url
# 0          https://doi.org/10.1016/j.jmii.2020.03.011
# 1          https://doi.org/10.1016/j.tmrv.2020.02.003
# 2          https://doi.org/10.1016/j.bbrc.2019.12.012
# 3  https://doi.org/10.1016/b978-0-12-801238-3.11488-6
# 4         https://doi.org/10.1016/j.physa.2019.04.266

# %%
query_corona_vs_cancer = '''
prefix oa:     <http://www.w3.org/ns/oa#>
prefix schema: <http://schema.org/>
prefix rdfs:   <http://www.w3.org/2000/01/rdf-schema#>

prefix wd:     <http://www.wikidata.org/entity/>
prefix wdt:    <http://www.wikidata.org/prop/direct/>

# wdt:P279 = subclass of 
# wdt:P31 = instance of
# wd:Q12078 = cancer
# wd:Q1134583 = coronavirus family = Coronaviridae

select distinct ?article ?dis1 ?dis1Label ?dis2 ?dis2Label #?dis2Subject

from <http://ns.inria.fr/covid19/graph/entityfishing>
from named <http://ns.inria.fr/covid19/graph/wikidata-named-entities>

where {
    # Look for 2 annotations of the same article with Wikidata URIs ?dis1 and ?dis2 

    # ?annot1 schema:about ?article; oa:hasBody ?dis1.
    # ?annot2 schema:about ?article; oa:hasBody ?dis2.
 
    graph <http://ns.inria.fr/covid19/graph/wikidata-named-entities>
    {
      # ?entity1 rdfs:label "cancer"@en. # ?entity1 is wd:Q12078
      
      { ?dis1 rdfs:label ?dis1Label.
        filter (?dis1 = ?entity1) } # ?dis1 is "cancer"

      UNION

      { ?dis1 wdt:P279 ?entity1;
              rdfs:label ?dis1Label. }  # ?dis1 is a subclass of "cancer" (at any depth)

      UNION

      { ?dis1 wdt:P31 ?entity1; 
              rdfs:label ?dis1Label. }  # ?dis1 is an instance of "cancer" or a subclass thereof



      # ?entity2 rdfs:label "Coronaviridae"@en. # ?entity2 is wd:Q1134583

      { ?dis2 rdfs:label ?dis2Label. 
      filter (?dis2 = ?entity2) }

      UNION

      { ?dis2 wdt:P279 ?entity2;
              rdfs:label ?dis2Label. } # ?dis2 is a subclass of "Coronaviridae" (at any depth)

      UNION

      { ?dis2 wdt:P31 ?entity2; 
              rdfs:label ?dis2Label. }  # ?dis2 is an instance of "Coronaviridae" or a subclass thereof

    }

    
}
order by ?dis1 ?dis2
limit 1000
'''

# %%
# %time df = sparql_service_to_dataframe(wds_Corese_Covid, query_Franck)
print(df.shape)
# Out:
# Wall time: 30.2 s
# (117, 5)

# %%
df#.loc[:, ['dis1Label', 'dis2Label']]
# Out:
#                                                                  article  \
# 0    http://ns.inria.fr/covid19/3dd399d305426e614eae51dd03fb48fa86c4d324
# 1    http://ns.inria.fr/covid19/c6a72d0b6a1510ac7ecb3e16179d9784990f6314
# 2    http://ns.inria.fr/covid19/7b620ef79c42118f157be2d9ab586fbd615b9fc6
# 3    http://ns.inria.fr/covid19/3dd399d305426e614eae51dd03fb48fa86c4d324
# 4    http://ns.inria.fr/covid19/c1e82ab3646382fd09d4e38c7041f89466f5028d
# 5    http://ns.inria.fr/covid19/ddba9808c2e5a41e0a27996ff5b59e4c09ae159a
# 6    http://ns.inria.fr/covid19/c1e82ab3646382fd09d4e38c7041f89466f5028d
# 7    http://ns.inria.fr/covid19/bdcac9db79352158e6d350d9fe430e5be20c22d6
# 8    http://ns.inria.fr/covid19/bdcac9db79352158e6d350d9fe430e5be20c22d6
# 9    http://ns.inria.fr/covid19/6b235789ef1785a5fbe39b0958ef4440eb482f54
# 10   http://ns.inria.fr/covid19/c7dc07727f9f0a09b060e1a3ca8acc3ee7d82bda
# 11   http://ns.inria.fr/covid19/d9dcb14ca476c86cc7c61f7650b76b47def235d4
# 12   http://ns.inria.fr/covid19/44ba5bad2568d5aeec5cf8a23291ebc933bc2ba3
# 13   http://ns.inria.fr/covid19/bdcac9db79352158e6d350d9fe430e5be20c22d6
# 14   http://ns.inria.fr/covid19/faec4bca24cb275ebc6c55e7cba3bd6a3b74df32
# 15   http://ns.inria.fr/covid19/e8d53e5527ae6c362e16b85de85a53cc3486f72f
# 16   http://ns.inria.fr/covid19/b5eea5100ecd167f491f314e660bd74423609194
# 17   http://ns.inria.fr/covid19/6ba80f58d066d9fb759bac1191c72267d94afd39
# 18   http://ns.inria.fr/covid19/092193fe026d59729062786d8f576b553e11a97d
# 19   http://ns.inria.fr/covid19/e30f5f76a403e0a60d32f941c32fb5e0cd08c458
# 20   http://ns.inria.fr/covid19/0dbe4d649872b1ecd33637cf4bcdeca805d2b714
# 21   http://ns.inria.fr/covid19/4f0ff8af7ea1d169470fd6a8baceba3749721764
# 79     http://www.wikidata.org/entity/Q29496
# 80     http://www.wikidata.org/entity/Q29496
# 81     http://www.wikidata.org/entity/Q33525
# 82    http://www.wikidata.org/entity/Q356033
# 83    http://www.wikidata.org/entity/Q356033
# 84    http://www.wikidata.org/entity/Q356033
# 85    http://www.wikidata.org/entity/Q356033
# 86    http://www.wikidata.org/entity/Q356033
# 87    http://www.wikidata.org/entity/Q356033
# 88    http://www.wikidata.org/entity/Q356033
# 89   http://www.wikidata.org/entity/Q3658562
# 90   http://www.wikidata.org/entity/Q4667072
# 91    http://www.wikidata.org/entity/Q467635
# 92    http://www.wikidata.org/entity/Q467635
# 93    http://www.wikidata.org/entity/Q467635
# 94    http://www.wikidata.org/entity/Q467635
# 95     http://www.wikidata.org/entity/Q47912
# 96     http://www.wikidata.org/entity/Q47912
# 97     http://www.wikidata.org/entity/Q47912
# 98     http://www.wikidata.org/entity/Q47912
# 99    http://www.wikidata.org/entity/Q500695
# 100   http://www.wikidata.org/entity/Q500695
# 101  http://www.wikidata.org/entity/Q5097977
# 102  http://www.wikidata.org/entity/Q5097977
# 103   http://www.wikidata.org/entity/Q570875
# 104   http://www.wikidata.org/entity/Q570875
# 105   http://www.wikidata.org/entity/Q612108
# 106  http://www.wikidata.org/entity/Q6488975
# 107  http://www.wikidata.org/entity/Q7159224
# 108   http://www.wikidata.org/entity/Q725345
# 109   http://www.wikidata.org/entity/Q809758
# 110   http://www.wikidata.org/entity/Q852423
# 111   http://www.wikidata.org/entity/Q938205
# 112   http://www.wikidata.org/entity/Q938205
# 113   http://www.wikidata.org/entity/Q938205
# 114   http://www.wikidata.org/entity/Q938205
# 115   http://www.wikidata.org/entity/Q938205
# 116   http://www.wikidata.org/entity/Q938205
#
#                             dis1Label  \
# 0            hepatocellular carcinoma
# 1            hepatocellular carcinoma
# 2            hepatocellular carcinoma
# 3            hepatocellular carcinoma
# 4            hepatocellular carcinoma
# 5            hepatocellular carcinoma
# 6            hepatocellular carcinoma
# 7                              cancer
# 8                              cancer
# 9                              cancer
# 10                             cancer
# 11                             cancer
# 12                             cancer
# 13                             cancer
# 14                      breast cancer
# 15                      breast cancer
# 16                      breast cancer
# 17                      breast cancer
# 18                      breast cancer
# 19                       fibrosarcoma
# 20                             glioma
# 21                             glioma
# 22                             glioma
# 23                             glioma
# 24                             glioma
# 25                             glioma
# 26                    cervical cancer
# 27                    cervical cancer
# 28              nasopharynx carcinoma
# 29                     ovarian cancer
# 30                        astrocytoma
# 31                        astrocytoma
# 32                        astrocytoma
# 33               head and neck cancer
# 34           Giant-cell tumor of bone
# 35           Giant-cell tumor of bone
# 36                           melanoma
# 37                           melanoma
# 38                           melanoma
# 39                           melanoma
# 40                           melanoma
# 41                           melanoma
# 42                           melanoma
# 43                           melanoma
# 44                           melanoma
# 45                           melanoma
# 46         acute lymphocytic leukemia
# 47                    prostate cancer
# 48                  colorectal cancer
# 49                  colorectal cancer
# 50                  colorectal cancer
# 51                  colorectal cancer
# 52                  colorectal cancer
# 53                  colorectal cancer
# 54                  colorectal cancer
# 55                     stomach cancer
# 56                   rhabdomyosarcoma
# 57                           lymphoma
# 58                           lymphoma
# 59                           lymphoma
# 60                           lymphoma
# 61                           lymphoma
# 62                           lymphoma
# 63                           lymphoma
# 64                           lymphoma
# 65                           lymphoma
# 66                           lymphoma
# 67                            sarcoma
# 68                       blood cancer
# 69                       blood cancer
# 70             acute myeloid leukemia
# 71                       glioblastoma
# 72                       glioblastoma
# 73                           leukemia
# 74                           leukemia
# 75                           leukemia
# 76                           leukemia
# 77                           leukemia
# 78                           leukemia
# 79                           leukemia
# 80                           leukemia
# 81                          carcinoma
# 82                     adenocarcinoma
# 83                     adenocarcinoma
# 84                     adenocarcinoma
# 85                     adenocarcinoma
# 86                     adenocarcinoma
# 87                     adenocarcinoma
# 88                     adenocarcinoma
# 89      non-small-cell lung carcinoma
# 90                            fibroma
# 91                   multiple myeloma
# 92                   multiple myeloma
# 93                   multiple myeloma
# 94                   multiple myeloma
# 95                        lung cancer
# 96                        lung cancer
# 97                        lung cancer
# 98                        lung cancer
# 99                     retinoblastoma
# 100                    retinoblastoma
# 101                  childhood cancer
# 102                  childhood cancer
# 103  in situ pulmonary adenocarcinoma
# 104  in situ pulmonary adenocarcinoma
# 105      acute promyelocytic leukemia
# 106         large-cell lung carcinoma
# 107              Pediatric ependymoma
# 108                  Kaposi's sarcoma
# 109              basal-cell carcinoma
# 110                  laryngeal cancer
# 111                     neuroblastoma
# 112                     neuroblastoma
# 113                     neuroblastoma
# 114                     neuroblastoma
# 115                     neuroblastoma
# 116                     neuroblastoma
#
#                                          dis2  \
# 0    http://www.wikidata.org/entity/Q16983356
# 1      http://www.wikidata.org/entity/Q278567
# 2      http://www.wikidata.org/entity/Q278567
# 3      http://www.wikidata.org/entity/Q290805
# 4      http://www.wikidata.org/entity/Q290805
# 5      http://www.wikidata.org/entity/Q290805
# 6     http://www.wikidata.org/entity/Q6926073
# 7     http://www.wikidata.org/entity/Q1134583
# 8      http://www.wikidata.org/entity/Q290805
# 9      http://www.wikidata.org/entity/Q290805
# 10     http://www.wikidata.org/entity/Q290805
# 11     http://www.wikidata.org/entity/Q290805
# 12     http://www.wikidata.org/entity/Q290805
# 13     http://www.wikidata.org/entity/Q454829
# 14     http://www.wikidata.org/entity/Q290805
# 15     http://www.wikidata.org/entity/Q290805
# 16     http://www.wikidata.org/entity/Q290805
# 17     http://www.wikidata.org/entity/Q290805
# 18    http://www.wikidata.org/entity/Q4902157
# 19    http://www.wikidata.org/entity/Q5032409
# 20     http://www.wikidata.org/entity/Q278567
# 21     http://www.wikidata.org/entity/Q290805
# 22     http://www.wikidata.org/entity/Q290805
# 23     http://www.wikidata.org/entity/Q290805
# 24    http://www.wikidata.org/entity/Q3560916
# 25    http://www.wikidata.org/entity/Q3560916
# 26     http://www.wikidata.org/entity/Q290805
# 27    http://www.wikidata.org/entity/Q5032409
# 28     http://www.wikidata.org/entity/Q290805
# 29     http://www.wikidata.org/entity/Q290805
# 30     http://www.wikidata.org/entity/Q290805
# 31     http://www.wikidata.org/entity/Q290805
# 69                                      Feline coronavirus
# 70                                             Coronavirus
# 71                                  Human coronavirus OC43
# 72   severe acute respiratory syndrome-related coronavirus
# 73                                             Coronavirus
# 74                                             Coronavirus
# 75                                             Coronavirus
# 76                                             Coronavirus
# 77                                             Coronavirus
# 78                                             Coronavirus
# 79                       Avian infectious bronchitis virus
# 80                                   Mouse hepatitis virus
# 81                                             Coronavirus
# 82                                               Torovirus
# 83                                               Torovirus
# 84                                             Coronavirus
# 85                                             Coronavirus
# 86                                             Coronavirus
# 87                                      Bovine coronavirus
# 88                                      Bovine coronavirus
# 89                                             Coronavirus
# 90                                             Coronavirus
# 91                                             Coronavirus
# 92                                             Coronavirus
# 93               Transmissible gastroenteritis coronavirus
# 94               Transmissible gastroenteritis coronavirus
# 95                                             Coronavirus
# 96                                             Coronavirus
# 97                                             Coronavirus
# 98                                             Coronavirus
# 99                                           Coronaviridae
# 100              Transmissible gastroenteritis coronavirus
# 101                                            Coronavirus
# 102                                            Coronavirus
# 103  severe acute respiratory syndrome-related coronavirus
# 104                                            Coronavirus
# 105              Transmissible gastroenteritis coronavirus
# 106                                            Coronavirus
# 107                                            Coronavirus
# 108                                            Coronavirus
# 109                                            Coronavirus
# 110                                            Coronavirus
# 111                                            Coronavirus
# 112                                            Coronavirus
# 113                                            Coronavirus
# 114                                            Coronavirus
# 115                                  Mouse hepatitis virus
# 116                                  Mouse hepatitis virus

# %%
import seaborn as sns
from collections import Counter

figure=plt.figure(figsize=(18, 18))

freq = Counter(df['dis1Label', 'dos2Label'])

cooccurrence_matrix = df.pivot('dis1Label', 'end_label', 'distance' ).fillna(0.0)#.astype('int32')

mask = distance_matrix[(distance_matrix < 100) & (distance_matrix > 0)]
#mask[np.triu_indices_from(mask)] = True

ax = sns.heatmap(distance_matrix, cmap='Greens_r',  annot=True, square=True, mask=mask.isna(), vmax=12.0)


ax.xaxis.tick_top() # x axis on top
plt.xticks(rotation=90)
ax.xaxis.set_label_position('top')
plt.show()

# %%
pd.DataFrame(df.groupby(['dis1Label', 'dis2Label']).size().reset_index()).columns
# Out:
# Index(['dis1Label', 'dis2Label', 0], dtype='object')

# %%
pd.DataFrame(df.groupby(['dis1Label', 'dis2Label'])).pivot('dis1Label', 'dis2Label', 0).fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'dis1Label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-472-b0c5a2c06160> in <module>
# ----> 1 pd.DataFrame(df.groupby(['dis1Label', 'dis2Label'])).pivot('dis1Label', 'dis2Label', 0).fillna(0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5921         from pandas.core.reshape.pivot import pivot
#    5922
# -> 5923         return pivot(self, index=index, columns=columns, values=values)
#    5924
#    5925     _shared_docs[
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     438             index = data.index
#     439         else:
# --> 440             index = data[index]
#     441         index = MultiIndex.from_arrays([index, data[columns]])
#     442
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     351             except ValueError:
#     352                 raise KeyError(key)
# --> 353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#     355     @Appender(_index_shared_docs["get_indexer"])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'dis1Label'
